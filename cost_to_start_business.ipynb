# %% [markdown]
# <a href="https://colab.research.google.com/github/marinabrts/marinabrts.github.io/blob/main/cost_to_start_business.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests, pandas as pd

# %%
url ="http://api.worldbank.org/v2/country/{}/indicator/IC.REG.COST.PC.ZS?date=2019&format=json"

#constructed a World Bank API link and selected countries of interest

country = ["CAN","USA","RUS","CHN","AUS","BRA","ISR","BOL","VEN","EGY",
           "NGA","TCD","ZAF","GBR","DNK","DEU","ESP","EST","ARE","IRN","IND",
           "KAZ","SGP","THA","IDN"]
html={}
for i in country:
  url_one = url.format(i)
  html[i] = requests.get(url_one).json()

#For loop that iterates over the country list and creates a url for each country code

# %%
html
# Out:
# {'ARE': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'AE', 'value': 'United Arab Emirates'},
#     'countryiso3code': 'ARE',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 17.2}]],
#  'AUS': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'AU', 'value': 'Australia'},
#     'countryiso3code': 'AUS',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 0.7}]],
#  'BOL': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'BO', 'value': 'Bolivia'},
#     'countryiso3code': 'BOL',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 37.3}]],
#  'BRA': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'BR', 'value': 'Brazil'},
#     'countryiso3code': 'BRA',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 4.2}]],
#  'CAN': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'CA', 'value': 'Canada'},
#     'countryiso3code': 'CAN',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 0.3}]],
#  'CHN': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'CN', 'value': 'China'},
#     'countryiso3code': 'CHN',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 1.1}]],
#  'DEU': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'DE', 'value': 'Germany'},
#     'countryiso3code': 'DEU',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 6.5}]],
#  'DNK': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'DK', 'value': 'Denmark'},
#     'countryiso3code': 'DNK',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 0.2}]],
#  'EGY': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#     'countryiso3code': 'EGY',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 20.3}]],
#  'ESP': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'ES', 'value': 'Spain'},
#     'countryiso3code': 'ESP',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 3.9}]],
#  'EST': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'EE', 'value': 'Estonia'},
#     'countryiso3code': 'EST',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 1}]],
#  'GBR': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'GB', 'value': 'United Kingdom'},
#     'countryiso3code': 'GBR',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 0}]],
#  'IDN': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'ID', 'value': 'Indonesia'},
#     'countryiso3code': 'IDN',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 5.7}]],
#  'IND': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'IN', 'value': 'India'},
#     'countryiso3code': 'IND',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 7.2}]],
#  'IRN': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'IR', 'value': 'Iran, Islamic Rep.'},
#     'countryiso3code': 'IRN',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 1.1}]],
#  'ISR': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'IL', 'value': 'Israel'},
#     'countryiso3code': 'ISR',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 2.7}]],
#  'KAZ': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'KZ', 'value': 'Kazakhstan'},
#     'countryiso3code': 'KAZ',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 0.2}]],
#  'NGA': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'NG', 'value': 'Nigeria'},
#     'countryiso3code': 'NGA',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 26.1}]],
#  'RUS': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'RU', 'value': 'Russian Federation'},
#     'countryiso3code': 'RUS',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 1}]],
#  'SGP': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'SG', 'value': 'Singapore'},
#     'countryiso3code': 'SGP',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 0.4}]],
#  'TCD': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'TD', 'value': 'Chad'},
#     'countryiso3code': 'TCD',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 169.3}]],
#  'THA': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'TH', 'value': 'Thailand'},
#     'countryiso3code': 'THA',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 3}]],
#  'USA': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'US', 'value': 'United States'},
#     'countryiso3code': 'USA',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 1}]],
#  'VEN': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'VE', 'value': 'Venezuela, RB'},
#     'countryiso3code': 'VEN',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 211.8}]],
#  'ZAF': [{'lastupdated': '2021-12-16',
#    'page': 1,
#    'pages': 1,
#    'per_page': 50,
#    'sourceid': '2',
#    'sourcename': 'World Development Indicators',
#    'total': 1},
#   [{'country': {'id': 'ZA', 'value': 'South Africa'},
#     'countryiso3code': 'ZAF',
#     'date': '2019',
#     'decimal': 1,
#     'indicator': {'id': 'IC.REG.COST.PC.ZS',
#      'value': 'Cost of business start-up procedures (% of GNI per capita)'},
#     'obs_status': '',
#     'unit': '',
#     'value': 0.2}]]}

# %%
my_values=[]
for i in country:

  value=html[i][1][0]['value']
  my_values.append(value)

  #For loop for obtaining "value" for each country code. For each country code, "value" is located in the 1st 
  # element of the list, inside the 0th element of the list inside it

# %%
my_names=[]
for i in country:
  name=html[i][1][0]['country']['value']
  my_names.append(name)

  #For loop for obtaining country name for each country code. For each country code, the name is located in the 1st
  # element of the list,inside the 0th element of the list inside it, inside the "country" key

# %%
my_names
# Out:
# ['Canada',
#  'United States',
#  'Russian Federation',
#  'China',
#  'Australia',
#  'Brazil',
#  'Israel',
#  'Bolivia',
#  'Venezuela, RB',
#  'Egypt, Arab Rep.',
#  'Nigeria',
#  'Chad',
#  'South Africa',
#  'United Kingdom',
#  'Denmark',
#  'Germany',
#  'Spain',
#  'Estonia',
#  'United Arab Emirates',
#  'Iran, Islamic Rep.',
#  'India',
#  'Kazakhstan',
#  'Singapore',
#  'Thailand',
#  'Indonesia']

# %%
df = pd.DataFrame(my_values, my_names)

# %%
df.columns=['Cost']

# %%
#create a data frame for cost of starting a business

# %%
df
# Out:
#                        Cost
# Canada                  0.3
# United States           1.0
# Russian Federation      1.0
# China                   1.1
# Australia               0.7
# Brazil                  4.2
# Israel                  2.7
# Bolivia                37.3
# Venezuela, RB         211.8
# Egypt, Arab Rep.       20.3
# Nigeria                26.1
# Chad                  169.3
# South Africa            0.2
# United Kingdom          0.0
# Denmark                 0.2
# Germany                 6.5
# Spain                   3.9
# Estonia                 1.0
# United Arab Emirates   17.2
# Iran, Islamic Rep.      1.1
# India                   7.2
# Kazakhstan              0.2
# Singapore               0.4
# Thailand                3.0
# Indonesia               5.7

# %%
df.to_csv("cost_csv")

# %%
from google.colab import files
files.download("cost_csv")

# %%
#save as cost_csv
